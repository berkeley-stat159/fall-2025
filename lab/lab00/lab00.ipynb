# %% [markdown]
# # Lab Session 0 - Introduction to Python
# > Friday 08-27-2025, 9AM-11AM & 1PM-3PM & 3PM-5PM
# >
# > Instructors: [Jimmy Butler](https://statistics.berkeley.edu/people/james-butler) & [Sequoia Andrade](https://statistics.berkeley.edu/people/sequoia-rose-andrade)

# %% [markdown]
# Welcome to the first lab session of Stat 159/259! Today, we will focus on getting your GitHub accounts set up on the Stat 159 DataHub and practicing a bit of python.
#
# 1. **Setting up Your GitHub Account.** If you want to learn more about how to work with GitHub and how GitHub internally works, we recommend you to take a look to [The curious coder’s guide to git](https://matthew-brett.github.io/curious-git/). After we all have a GitHub account, we will ask you to complete this [form](https://docs.google.com/forms/d/e/1FAIpQLScYkUzs3ICdL2atcoqsIoqgShSe_wx6IfCw2cHHDxGnfrTngQ/viewform) so we can add you to GitHub Classroom.
#
# 1. **Warming up with Python.** We will follow the Python tutorial written by Jake VanderPlas, [A Whirlwind Tour of Python](https://jakevdp.github.io/WhirlwindTourOfPython). We also invite you to play with the [PythonTutor](https://pythontutor.com), where you can see how variables are referenced to objects as you write your code.
#
# We will be working in the [JupyterHub](https://stat159.datahub.berkeley.edu/hub/login?next=%2Fhub%2F) for the full course, which has the libraries and tools we will be using during the semester. Why do we use the Hub? Well, it is quite convenient since you don't need to install anything in your personal computer and you don't need to worry about having installed all the required packages with their right version.
#
# We are going to use Python for all the projects and homeworks in this course. However, it is important to remark that many of the concepts we will see in this course apply to other programming languages too (Julia, R, C, etc). Some good reasons for working in Python include
#
# - Interpreted instead of compiled
# - Clean syntax
# - Object oriented (attributes + methods), convenient language constructs
# - Variables can access large data structures by reference, without making a copy (speed and memory efficient).

# %% [markdown]
# ### Useful Links
#
# - [JupyterHub](https://stat159.datahub.berkeley.edu)
# - [GitHub Organization](https://github.com/UCB-stat-159-f25)
# - [bCourses](https://bcourses.berkeley.edu/courses/1546508)
# - [Ed Discussion](https://edstem.org/us/courses/84806/discussion)
# - [Google Form](https://docs.google.com/forms/d/e/1FAIpQLScYkUzs3ICdL2atcoqsIoqgShSe_wx6IfCw2cHHDxGnfrTngQ/viewform?usp=dialog)

# %% [markdown]
# ## 1. Logging into the Stat 159 JupyterHub
#
# + Go to stat159.datahub.berkeley.edu
# + Log in if prompted! All Berkeley students should have access to the DataHub.

# %% [markdown]
# ## 2. Setting up Your GitHub Account
#
# + If you don't have a GitHub account yet, you can create one following this [link](http://github.com/) (please DON'T use github.berkeley.edu to create a GitHub account).
#
# + Next, open a terminal window by clicking *File*, *New*, and *Terminal*
#
# + You can use the following syntax in the terminal to configure your GitHub credentials for all repositories that will be on this Hub.
#
# ```bash
# git config --global <setting> <option>
# ```
#
# For example, you can configure your name and email:
#
# ```bash
# git config --global user.name "Fernando Perez"
# git config --global user.email "fernando.perez@berkeley.edu"
# ```
#
# Note: the above commands are to be executed in the terminal. You can also execute the same command in bash from a notebook by adding a `!` in front of the command inside a cell. In general, it is recommendable to run bash commands from the terminal.

# %%
# !git config --global user.name "Fernando Perez"

# %% [markdown]
# ## 3. Getting Added to the GitHub Classroom
#
# For homeworks and projects in this course, we will be using [GitHub Classroom](https://classroom.github.com). Once you all have a GitHub account created, we will add you to the GitHub classroom. Details on how to submit assignments using this service will be provided next lab, after next Wednesday's lecture on GitHub.
#
# >
# > Once you have your GitHub account, please take a few minutes to complete this [form](https://docs.google.com/forms/d/e/1FAIpQLScYkUzs3ICdL2atcoqsIoqgShSe_wx6IfCw2cHHDxGnfrTngQ/viewform?usp=dialog) so that we can add you to the GitHub classroom.
# >

# %% [markdown]
# ## 4. Cloning your own local copy of the Stat 159 course website
#
# All of the materials on the course website are actually all available on a [public GitHub repository](https://github.com/UCB-stat-159-f25/site)! This repo can also be accessed by clicking the GitHub icon in the upper right corner of the course website.
#
# ![image.png](attachment:922c3bda-7380-4b60-ad4c-ab8f6f6ccb61.png)
#
# It will be useful to maintain a local copy of this GitHub repository on this JupyterHub, pulling any changes the course staff makes over the duration of the semester. It will also give you local copies of any notebooks from lecture and lab for you to run yourself!
#
# To do so, open up a Terminal and run the following:
#
# ```bash
# git clone https://github.com/UCB-stat-159-f25/site
# ```
#
# You should see a folder appear on the left named 'site'.
#
# Now, you of course can navigate to the lab folder and find this notebook and begin working on the exercises youself. However, to avoid any future merge conflicts with changes we might make, and for you to save your work, it will be useful for you to make a copy of this lab notebook in a directory *outside* of the 'site' folder.
#
# Our suggestion is to make a new folder for each lab, and copy and paste that week's lab notebook into that directory. This can be done in the following way:
#
# **Step 1:** Right-click in the directory to the left and select 'New Folder'
#
# ![image.png](attachment:21810a13-9428-4149-afaa-7b9a3a82ba7f.png)
#
# **Step 2:** Name it 'lab0'
#
# **Step 3:** In the site repository, navigate 'lab' > 'lab00'.
#
# **Step 4:** Right click on 'lab00.ipynb', and copy the notebook.
#
# **Step 5:** Click on the folder icon to bring yourself back to the home directory. Find the 'lab0' folder, click it, and right-click to paste the notebook into that folder.
#
# ![image.png](attachment:1a80f692-18df-471c-8ac8-da74b74a3128.png)
#
# Now you have a copy of this notebook on your DataHub that will not be tracked or overwritten. Feel free to work on the exercises today in that copy.

# %% [markdown]
# ## 5. Authenticating to Push/Pull GitHub Repositories

# %% [markdown]
# Usually when pushing changes to or pulling changes from a remote GitHub repository using a cloud-based service like this JupyterHub, GitHub requires you to enter your username and password *each* time. This can get pretty annoying especially if you have many changes to push, so we will use a workaround that gives the Stat 159 JupyterHub push/pull permissions automatically. The workaround involves running cells in a Jupyter notebook that handles the authentication steps. The following steps show how to access the notebook, favorite it so you can save it for future use, and how to authenticate by executing the cells.
#
# 1. In your local copy of the 'site' repository, navigate 'lectures' > 'intro-git'. Copy the 'GHAUTH.ipynb' notebook and paste it into your home directory (similar to what we did for the lab notebook).
# 2. Right click the file and select Add Favorite
#
# ![image.png](attachment:4235afd0-4c8f-4795-991f-15125ae1e505.png)
#
# 3. You should see a new 'Favorites' tab appear on the left with the notebook we copied. Open the notebook and run through the steps to authenticate!
#
# ![image.png](attachment:6020a9f4-6412-4827-9144-b6e6bb791630.png)
#
# Now, we won't need to enter our login credentials if we push or pull! Note this only lasts for 8 hours, so you will need to go back into this notebook to reauthenticate. That's why we favorited it!

# %% [markdown]
# ## 6. Warming up with Python
#
# For today's session, we will follow [A Whirlwind Tour of Python](https://jakevdp.github.io/WhirlwindTourOfPython/). You can see the contents of the book online, but you can also clone the repository of the book with the following command
#
# ```bash
# git clone https://github.com/jakevdp/WhirlwindTourOfPython.git
# ```
#
# Whenever you are doing this from the terminal or a notebook, remember to run this command from the directory you want the repository to be cloned.
#
# It is important that you are familiar with the contents of chapters 1-8, which include some introductory python syntax and data structures. If not, please take a few minutes to go thought these notebooks and get familiar with them. These concepts include:
# - Basic operations (arithmetic, comparison, assignment, ...)
# - Manipulation of simple data structures (lists, dictionaries, tuples)
# - Control flow (for loops, conditional statements)

# %% [markdown]
# ### 2.1. Functions
#
# For this part of the lecture, we recommend following Chapter 9. As we write more and more code, keeping track of what each piece is doing can became quite difficult. Functions allow us to encapsulate pieces of code that are responsible for addressing a more specific task. Then, a nice piece of code looks like different functions (sometimes concatenated one to each other) doing different tasks in order to archive a final mayor goal.
#
# Functions receive different kind of arguments. The scope of this variables is always local, meaning that the variable name is declared *just* inside the function.

# %%
from math import gcd      # we import the great common divisor function from math

def get_coprimes(L, d=2):
    """
    Function to extract the coprimes elements of a list with respect to some given integer
    
    Arguments:
        - L: list with integers 
        - d: integer against with the coprimality is evaluated
        
    Outputs:
        - res: list of subelements of L that are coprime with d
    """

# %%
L0 = [1, 2, 3, 4, 5, 6]

get_coprimes(L0)
# Out:
# [1, 3, 5]

# %%
get_coprimes(L0, 3)
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# A few comments about this last example:
# 1. Suppose we want to ignore the trivial case of every number being coprimer with `1`. What can we do then? Do we add another conditional statement?
# 2. What do we do if `L` has negative values?
# 3. What do we do if there are values in `L` that are no integers?
# 4. Can you think in ways of implementing `get_coprimes` by using a different kind of data structures?
# 5. Is it possible to extent the scope of the variables inside the function (eg, to obtain the value of `res` inside `get_coprimes` outside the scope of the function)?
#
# We can solve some of these problems by hand. In the next section we will see how to add exceptions for conflictive cases.
#
# Something really useful about functions in Python is that we can add flexible arguments. These are divided into
# - Simple arguments: `*args`
# - Keyword arguments: `**kwargs`
#
# The `*` operator is usually called the unpacking operator.

# %%
def catch_all(*args, **kwargs):
    print("args =", args)
    print("kwags =", kwargs)
    
    if len(args) == 3:
        print(args[1])
    print(kwargs['b'])

# %%
catch_all(1, 2, 3, b=1.1, c=1.2)
# Out:
# args = (1, 2, 3)
# kwags = {'b': 1.1, 'c': 1.2}
# 2
# 1.1

# %%
def sum_args(*args, **kwargs):
    
    res = 0
    
    for x in args:
        res += x
        
    if "factor" in kwargs.keys():
        res *= kwargs["factor"]
        
    return res

# %%
sum_args(1, 2, 3, 5, factor=1)
# Out:
# 11

# %% [markdown]
# We can also define anonymous functions, usually referred by the symbol `lambda`. This are useful for different things (for example, we will see how useful they are when dealing with dataframes in Pandas)

# %%
add_one = lambda x: x+1

# %%
add_one(1.2)
# Out:
# 2.2

# %%
sorted(L0, key = lambda x : x%2)
# Out:
# [2, 4, 6, 1, 3, 5]

# %% [markdown]
# Why is Python an object oriented program if we are all time working with functions... well, functions are also objects:

# %%
def duplicate(x):
    return 2 * x

def apply(x, func):
    return func(x)

apply(2, duplicate)
# Out:
# 4

# %% [markdown]
# The function `apply` is what we call a higher-order function, since it takes another function as an argument. Another examples of higher-order functions in Python are `map` and `filter`.
#
# We can also access the different attributes of a Python function:

# %%
# ?dir
# Out:
# Docstring:
# dir([object]) -> list of strings
#
# If called without an argument, return the names in the current scope.
# Else, return an alphabetized list of names comprising (some of) the attributes
# of the given object, and of attributes reachable from it.
# If the object supplies a method named __dir__, it will be used; otherwise
# the default dir() logic is used and returns:
#   for a module object: the module's attributes.
#   for a class object:  its attributes, and recursively the attributes
#     of its bases.
#   for any other object: its attributes, its class's attributes, and
#     recursively the attributes of its class's base classes.
# Type:      builtin_function_or_method

# %%
dir(duplicate)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# and also define new attributes:

# %%
duplicate.__version__ = "0.0.1"
duplicate.__version__
# Out:
# '0.0.1'

# %% [markdown]
# ### 2.2. Errors and Exceptions
#
# Different kinds of errors that occur as we write code include syntax, runtime and semantic errors. Specially for runtime errors, Python give us a clue about what kind or error may happened during the execution of our code. For example,

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1928/1455669704.py in <module>
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero

# %%
my_dict = {'a':1, 'b':2}
my_dict['c']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1928/145831508.py in <module>
#       1 my_dict = {'a':1, 'b':2}
# ----> 2 my_dict['c']
#
# KeyError: 'c'

# %%
my_dict + {'c':3}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1928/1025278159.py in <module>
# ----> 1 my_dict + {'c':3}
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %% [markdown]
# There are many more different kind of built-in exceptions in Python. You can find some more examples in this [link](https://docs.python.org/3/library/exceptions.html). A general `RuntimeError` is raised when the detected error doesn't fall in any of the other categories.
#
# There are different ways of dealing with runtime errors in Python, there include the
# - `try`...`except` clause
# - `raise` statement

# %%
a = 1    # numerator
b = 0    # denominator

# %%
try:
    print("I was here")
    a / b
    print("Was I here?")
except:
    print("Something wrong happened")
# Out:
# I was here
# Something wrong happened

# %%
a = 1
b = 0

if b == 0:
    raise ValueError("b must be different than zero.")
a / b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [42], in <module>
#       2 b = 0
#       4 if b == 0:
# ----> 5     raise ValueError("b must be different than zero.")
#       6 a / b
#
# ValueError: b must be different than zero.

# %% [markdown]
# In the following example, we use both `try`...`except` and `raise`, but it's not working as we may expect. Can you identify the problem?

# %%
a = 1
b = 0

try:
    print("I was here")
    if b == 0:
        raise ValueError("b must be different than zero.")
    a / b
    print("Was I here?")
except: 
    print("Something wrong happen")
# Out:
# I was here
# Something wrong happen

# %% [markdown]
# Exceptions, as everything in Python, are objects too. This means we can define new exception errors and deal with them as if they were classes:

# %%
class MyNewException(Exception):
    pass

# %% [markdown]
# ## Homework 0
#
# The idea of this homework is to put into practice your Python skills and also show you how the workflow of submitting and reviewing homeworks/projects will work using GitHub Classroom.
#
# For now, we are going to clone a public repository with HW0 into the this JupyterHub, and work from there. You can find the [repository in the course GitHub site](https://github.com/UCB-stat-159-f25/hw00) or clone it directly:
# ```bash
# git clone https://github.com/UCB-stat-159-f25/hw00.git
# ```
# This first homework is NOT going to be graded; however, it has excerises of skills you will use throughout the semester. Next week, we will go over how one would submit this assignment using the GitHub classroom, as practice for how you will submit your future homeworks and projects.
