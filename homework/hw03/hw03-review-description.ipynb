# %% [markdown]
# # Homework 3 Peer Review

# %% [markdown]
# * **Statistics 159/259, Fall 2025**
# * **Due Friday 11/17/2025, 11:59PM PT**
# * Assignment type: **individual**.

# %% [markdown]
# In HW 3, we added some more structure to our LIGO repositories from HW 2, turning our `ligotools` local package into an installable python package, adding tests of its functions, and creating a Makefile to execute useful workflows with single terminal commands. In this peer review, you will be testing out the various functionalities your peer implemented as part of the HW 3 assignment, assuming the role of another researcher seeking to reproduce and appraise your peer's results.
#
# For each of the following items to check, please raise an issue in your partner's repo that answers the prompts/questions. If any of the items are missing to a degree that impedes your ability to do the tasks, mention this in the issue you raise.
#
# To get started, fork your peer's repo and clone the fork into your Stat159 Datahub session.

# %% [markdown]
# ## 1. Building the Conda Environment
#
# First, try to use the your peer's `env` command in their `Makefile` to build the conda environment used in the notebook. The original assignment did not specify the exact manner in which this was to be done: your peer may have the command create a conda environment from scratch, or update an existing conda environment if it has already been installed, or both. Check your peer's `Makefile` to see how they decided to answer this question.
#
# *If their command creates a new conda environment from the `environmnent.yml` file:*
# 1. Edit `name` field in the `environment.yml` file so that the name is `ligo-peer` instead of `ligo` (this is to avoid a conflict with the `ligo` environment you yourself installed in the completion of this assignment)
# 2. Run their make command to create the environment
#
# *If their command updates an existing conda environment using the `environment.yml` file:*
# 1. Create a new conda environment, and name it the same name their make command assumes (usually following the `-n` flag in the `conda update` command). If there is no `-n` flag, name your conda environment `ligo-peer` when you create it, and add the `-n` flag to their `conda update` call in their make command, using the the `ligo-peer` name.
# 2. Run the make command.
#
# Open an issue in GitHub describing how successful this part was. If there are problems with installing the environment using the make command, document and describe them in the GitHub issue for this part, referring to the specific line in the Makefile in your issue.
#
# :::{note}
# We will need a functional environment to reproduce the output from the notebook. If you could not build the conda environment from the `Makefile` command, build it yourself from the `environment.yml` in the terminal, naming it `ligo-peer`.
# :::

# %% [markdown]
# ## 2. Installing the `ligotools` package
#
# Activate the conda environment you created in the last step. Navigate to your peer's `ligotools` folder. You should see, among other files, a `pyproject.toml` file and another folder called `ligotools` that has the modules and tests in it.
#
# :::{note}
# If this does not match your peer's file structure, spend a minute rearranging the files and directories so that, in the root directory of the repo, there is a folder called `ligotools`, that itself has the `pyproject.toml` file and another `ligotools` folder with the tests and modules.
# :::
#
# Inside the `ligotools` package folder (the outer one), install the package into your environment via `pip install .`
#
# Open an issue and comment if this worked.

# %% [markdown]
# ## 3. Reproduce the output from `LOSC_Event_tutorial.ipynb`
#
# First, make the environment we just created in Step 1 available for use in a Jupyter Notebook (see this [lecture material](https://stat159.berkeley.edu/fall-2025/lectures/environments/environments/#using-an-environment-in-your-notebooks)).
#
# Open the notebook and run through each cell. Open and issue, remarking if all the cells run, and if all the output is created in the respective `audio` and `figures` directories.

# %% [markdown]
# ## 4. Clean the Outputs with `make clean`
#
# Run the `make clean` command from your peer's `Makefile`. Open an issue: did all the outputs in the output folders get cleared?

# %% [markdown]
# ## 5. Run the `ligotools` tests
#
# Navigate to the root directory of your peer's `ligotools` package, and run `pytest ligotools`. Do the tests run? Do they pass? Open a GitHub issue and comment.

# %% [markdown]
# ## 6. Local Website Build + GitHub Pages Build
#
# Are you able to build a local copy of your peer's website on the Datahub? Do they have a link to their GitHub Pages website displayed in their repo, and was the website successfully deployed? Open an issue and comment.
