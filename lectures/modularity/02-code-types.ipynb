# %% [markdown]
# # Code Types Demonstration
#
# Notebook to demonstrate different code running styles, including:
# - Jupyter notebooks
# - Python scripts and Python modules
# - Python in the terminal
# - Ipython in the terminal
# - Ipython console
#
# ## Jupyter Notebook Code
#
# We can directly write functions in notebooks and use them in later cells.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd

# %%
def sample_normal_dist(mu: float, sigma: float, n: int, plot=True):
    """
    Samples from a normal distribution with given parameters with 
    the option to plot

    Args:
        mu (float): mean.
        sigma (float): standard deviation.
        n (int): number of samples.
    Returns:
        np.array: array of samples.
    """
    # Generate random samples from a normal distribution
    samples = np.random.normal(loc=mu, scale=sigma, size=n)
    if plot:
        # Visualize the distribution of the samples using a histogram
        plt.hist(samples, bins=30, density=True, alpha=0.6, color='g')
        plt.title('Histogram of Samples from Normal Distribution')
        plt.xlabel('Value')
        plt.ylabel('Probability Density')
        plt.grid(True)
        plt.show()
    # Display the mu and sigma
    df = pd.DataFrame({"True": [mu, sigma], 
                       "Sample": [np.mean(samples), np.std(samples)]}, 
                      index=["Mu", "Sigma"])
    display(df.round(3))
    return samples

# %%
mu = 0
sigma = 1
n = 1000
sample_normal_dist(mu, sigma, n)
# Out:
#        True  Sample
# Mu        0  -0.028
# Sigma     1   1.002
# array([-2.17066248e-01, -1.46505489e+00, -2.79719103e+00,  1.55784126e+00,
#         8.70742201e-01,  1.44948320e-01,  6.64689451e-02, -7.10919354e-01,
#         1.33287534e+00,  1.22536931e+00, -6.44943157e-01,  4.65895615e-02,
#         2.13873500e+00,  1.13147595e-01,  5.78273091e-01,  1.40453713e-01,
#         6.59300892e-01,  6.59095089e-01,  7.20005446e-01, -1.78108395e-01,
#         7.04861388e-01,  1.19653006e+00,  1.23490434e+00, -1.15965281e-01,
#         6.33398784e-01, -4.80956627e-02,  1.31559411e+00, -1.61403240e+00,
#         6.56213905e-01, -5.87761906e-01, -5.39186060e-01, -6.45083082e-01,
#         5.02225008e-01, -5.58749115e-01,  4.90964278e-02,  4.62004710e-01,
#        -1.75515153e+00,  2.32809650e+00, -1.52121495e+00, -1.02872360e+00,
#        -2.82387916e-01, -9.42796853e-01,  6.90487073e-01, -4.25596710e-02,
#         1.02030175e-01,  2.17375362e+00, -8.22859579e-01,  1.31955799e+00,
# ...

# %% [markdown]
# ## Importing a Local Module
#
# Instead of writing the function directly in the notebook, we can import it from a local module which contains the function definition. This is convienent because we could then reuse the function again in other notebooks and future projects.

# %%
# show using local import
from example_python_script import sample_normal_dist_module

# %%
mu = 0
sigma = 1
n = 1000
sample_normal_dist_module(mu, sigma, n)
# Out:
#        True  Sample
# Mu        0  -0.000
# Sigma     1   0.995
# array([-5.63013479e-01, -2.63258448e-01,  2.92209368e-03,  4.30012228e-01,
#         9.31736143e-01, -7.54381079e-01, -7.75720709e-01,  1.64710728e+00,
#        -1.69255142e+00,  3.53332883e-01, -3.20139165e-01,  5.76919400e-01,
#         6.30121088e-01, -4.99456294e-02,  7.56503220e-01, -3.50046717e+00,
#         5.56184439e-01, -2.22816115e-01,  3.20908039e-01, -4.72302773e-01,
#         2.57494452e-01, -5.68509714e-01,  1.26038267e+00, -6.96483291e-01,
#         5.12906169e-01, -2.09654002e-01,  1.78702067e-01, -1.47640359e+00,
#        -1.87398669e+00, -3.01991924e-02, -3.28715222e-01,  1.05805001e+00,
#         5.91245212e-01,  6.15479422e-02,  1.00972475e+00, -1.59837448e-01,
#        -7.43539032e-01, -2.03170808e+00,  3.32975114e-01, -4.66288142e-01,
#        -3.64044042e-01, -4.02553635e-01,  5.85850383e-01, -1.11611279e+00,
#        -2.50392274e-01,  6.11999804e-01, -1.02072207e+00, -1.17597840e+00,
# ...
